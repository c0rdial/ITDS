# %% [markdown]
# ### Pandas (Part 1)

# %% [markdown]
# #### creating your first pandas dataframe (from csv)

# %%
import pandas as pd

# %%
titanic = pd.read_csv("downloads/titanic.csv")

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
print (titanic)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
pd.options.display.max_rows
# Out:
# 60

# %%
pd.options.display.min_rows
# Out:
# 10

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.head(3)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN

# %%
titanic.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked deck
# 886         0       2    male  27.0      0      0  13.00        S  NaN
# 887         1       1  female  19.0      0      0  30.00        S    B
# 888         0       3  female   NaN      1      2  23.45        S  NaN
# 889         1       1    male  26.0      0      0  30.00        C    C
# 890         0       3    male  32.0      0      0   7.75        Q  NaN

# %%
titanic.tail(20)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 871         1       1  female  47.0      1      1  52.5542        S    D
# 872         0       1    male  33.0      0      0   5.0000        S    B
# 873         0       3    male  47.0      0      0   9.0000        S  NaN
# 874         1       2  female  28.0      1      0  24.0000        C  NaN
# 875         1       3  female  15.0      0      0   7.2250        C  NaN
# 876         0       3    male  20.0      0      0   9.8458        S  NaN
# 877         0       3    male  19.0      0      0   7.8958        S  NaN
# 878         0       3    male   NaN      0      0   7.8958        S  NaN
# 879         1       1  female  56.0      0      1  83.1583        C    C
# 880         1       2  female  25.0      0      1  26.0000        S  NaN
# 881         0       3    male  33.0      0      0   7.8958        S  NaN
# 882         0       3  female  22.0      0      0  10.5167        S  NaN
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %% [markdown]
# ### Python built-in functions & dataframe attributes and methods

# %% [markdown]
# - len(): return the number of items in an object

# %%
len(titanic)
# Out:
# 891

# %% [markdown]
# - round(): the number of decimals to use when rounding the numner - default value 0

# %%
round(titanic, 2)
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked deck
# 0           0       3    male  22.0      1      0   7.25        S  NaN
# 1           1       1  female  38.0      1      0  71.28        C    C
# 2           1       3  female  26.0      0      0   7.92        S  NaN
# 3           1       1  female  35.0      1      0  53.10        S    C
# 4           0       3    male  35.0      0      0   8.05        S  NaN
# ..        ...     ...     ...   ...    ...    ...    ...      ...  ...
# 886         0       2    male  27.0      0      0  13.00        S  NaN
# 887         1       1  female  19.0      0      0  30.00        S    B
# 888         0       3  female   NaN      1      2  23.45        S  NaN
# 889         1       1    male  26.0      0      0  30.00        C    C
# 890         0       3    male  32.0      0      0   7.75        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic.shape
# Out:
# (891, 9)

# %% [markdown]
# 891 * 9 = 8019
#
# The number of elements in the dataframe

# %%
titanic.size
# Out:
# 8019

# %% [markdown]
# .columns = display the name of columns in the dataframe

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'deck'],
#       dtype='object')

# %%
titanic.head(n=2)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C

# %%
titanic[["age","sex"]]
# Out:
#       age     sex
# 0    22.0    male
# 1    38.0  female
# 2    26.0  female
# 3    35.0  female
# 4    35.0    male
# ..    ...     ...
# 886  27.0    male
# 887  19.0  female
# 888   NaN  female
# 889  26.0    male
# 890  32.0    male
#
# [891 rows x 2 columns]

# %%
type(titanic["age"])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## Search using index

# %%
titanic.iloc[:,[0,1,3]]
# Out:
#      survived  pclass   age
# 0           0       3  22.0
# 1           1       1  38.0
# 2           1       3  26.0
# 3           1       1  35.0
# 4           0       3  35.0
# ..        ...     ...   ...
# 886         0       2  27.0
# 887         1       1  19.0
# 888         0       3   NaN
# 889         1       1  26.0
# 890         0       3  32.0
#
# [891 rows x 3 columns]

# %% [markdown]
# ## search using Range

# %%
titanic.iloc[:, 0:3]
# Out:
#      survived  pclass     sex
# 0           0       3    male
# 1           1       1  female
# 2           1       3  female
# 3           1       1  female
# 4           0       3    male
# ..        ...     ...     ...
# 886         0       2    male
# 887         1       1  female
# 888         0       3  female
# 889         1       1    male
# 890         0       3    male
#
# [891 rows x 3 columns]

# %% [markdown]
# ## Select using name of columns

# %%
titanic.age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %% [markdown]
# ## Filtering dataframe with condition (AND)

# %%
((titanic.sex == 'male')& (titanic.age >=14))
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Length: 891, dtype: bool

# %%
titanic[(titanic.sex =='male') & (titanic.age >=14)].loc[:,["survived", "pclass", "sex","age"]]
# Out:
#      survived  pclass   sex   age
# 0           0       3  male  22.0
# 4           0       3  male  35.0
# 6           0       1  male  54.0
# 12          0       3  male  20.0
# 13          0       3  male  39.0
# ..        ...     ...   ...   ...
# 883         0       2  male  28.0
# 884         0       3  male  25.0
# 886         0       2  male  27.0
# 889         1       1  male  26.0
# 890         0       3  male  32.0
#
# [416 rows x 4 columns]

# %%
titanic[(titanic.sex =='female') & (titanic.age < 14)].loc[:,["survived", "pclass", "sex","age"]]
# Out:
#      survived  pclass     sex    age
# 10          1       3  female   4.00
# 24          0       3  female   8.00
# 43          1       2  female   3.00
# 58          1       2  female   5.00
# 119         0       3  female   2.00
# 147         0       3  female   9.00
# 172         1       3  female   1.00
# 184         1       3  female   4.00
# 205         0       3  female   2.00
# 233         1       3  female   5.00
# 237         1       2  female   8.00
# 297         0       1  female   2.00
# 374         0       3  female   3.00
# 381         1       3  female   1.00
# 419         0       3  female  10.00
# 446         1       2  female  13.00
# 448         1       3  female   5.00
# 469         1       3  female   0.75
# 479         1       3  female   2.00
# 530         1       2  female   2.00
# 535         1       2  female   7.00
# 541         0       3  female   9.00
# 542         0       3  female  11.00
# 618         1       2  female   4.00
# ...

# %%
mask1=titanic.sex == 'male'
mask1.head()
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# Name: sex, dtype: bool

# %%
mask2 = titanic.age >= 14
mask2.head()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: age, dtype: bool

# %%
(mask1 & mask2).head()
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
male_adult = titanic.loc[mask1 & mask2, ["survived","pclass","sex","age"]]
male_adult.head(10)
# Out:
#     survived  pclass   sex   age
# 0          0       3  male  22.0
# 4          0       3  male  35.0
# 6          0       1  male  54.0
# 12         0       3  male  20.0
# 13         0       3  male  39.0
# 20         0       2  male  35.0
# 21         1       2  male  34.0
# 23         1       1  male  28.0
# 27         0       1  male  19.0
# 30         0       1  male  40.0

# %% [markdown]
# ## Filtering dataframe with conditions (OR)

# %%
mask1 = titanic.sex == 'female'
mask1.head()
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4    False
# Name: sex, dtype: bool

# %%
mask2 = titanic.age < 14
mask2.head(10)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7     True
# 8    False
# 9    False
# Name: age, dtype: bool

# %%
titanic.loc[mask1 | mask2]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 7           0       3    male   2.0      3      1  21.0750        S  NaN
# 8           1       3  female  27.0      0      2  11.1333        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 880         1       2  female  25.0      0      1  26.0000        S  NaN
# 882         0       3  female  22.0      0      0  10.5167        S  NaN
# 885         0       3  female  39.0      0      5  29.1250        Q  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
#
# [351 rows x 9 columns]

# %%
wom_or_chi = titanic.loc[mask1 | mask2, ["survived", "pclass", "sex","age"]]
wom_or_chi.head()
# Out:
#    survived  pclass     sex   age
# 1         1       1  female  38.0
# 2         1       3  female  26.0
# 3         1       1  female  35.0
# 7         0       3    male   2.0
# 8         1       3  female  27.0

# %%
wom_or_chi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 351 entries, 1 to 888
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  351 non-null    int64
#  1   pclass    351 non-null    int64
#  2   sex       351 non-null    object
#  3   age       298 non-null    float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 13.7+ KB

# %%
g1 = wom_or_chi.groupby(by="survived")
l1 = list(g1)
l1
# Out:
# [(0,
#        survived  pclass     sex   age
#   7           0       3    male   2.0
#   14          0       3  female  14.0
#   16          0       3    male   2.0
#   18          0       3  female  31.0
#   24          0       3  female   8.0
#   ..        ...     ...     ...   ...
#   854         0       2  female  44.0
#   863         0       3  female   NaN
#   882         0       3  female  22.0
#   885         0       3  female  39.0
#   888         0       3  female   NaN
#
#   [97 rows x 4 columns]),
#  (1,
#        survived  pclass     sex   age
#   1           1       1  female  38.0
#   2           1       3  female  26.0
#   3           1       1  female  35.0
#   8           1       3  female  27.0
#   9           1       2  female  14.0
#   ..        ...     ...     ...   ...
#   874         1       2  female  28.0
#   875         1       3  female  15.0
#   879         1       1  female  56.0
#   880         1       2  female  25.0
# ...

# %% [markdown]
# ### creating  columns based on other columns

# %%
1912-titanic.age
# Out:
# 0      1890.0
# 1      1874.0
# 2      1886.0
# 3      1877.0
# 4      1877.0
#         ...
# 886    1885.0
# 887    1893.0
# 888       NaN
# 889    1886.0
# 890    1880.0
# Name: age, Length: 891, dtype: float64

# %%
titanic["YOB"] = 1912-titanic.age

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck     YOB
# 0         0       3    male  22.0      1      0   7.2500        S  NaN  1890.0
# 1         1       1  female  38.0      1      0  71.2833        C    C  1874.0
# 2         1       3  female  26.0      0      0   7.9250        S  NaN  1886.0
# 3         1       1  female  35.0      1      0  53.1000        S    C  1877.0
# 4         0       3    male  35.0      0      0   8.0500        S  NaN  1877.0

# %%
titanic.sibsp + titanic.parch
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 886    0
# 887    0
# 888    3
# 889    0
# 890    0
# Length: 891, dtype: int64

# %%
titanic["Relative"] = titanic.sibsp + titanic.parch

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck  \
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN
#
#       YOB  Relative
# 0  1890.0         1
# 1  1874.0         1
# 2  1886.0         0
# 3  1877.0         1
# 4  1877.0         0

# %%
titanic.drop(columns = ["sibsp","parch"], inplace = False)
# Out:
#      survived  pclass     sex   age     fare embarked deck     YOB  Relative
# 0           0       3    male  22.0   7.2500        S  NaN  1890.0         1
# 1           1       1  female  38.0  71.2833        C    C  1874.0         1
# 2           1       3  female  26.0   7.9250        S  NaN  1886.0         0
# 3           1       1  female  35.0  53.1000        S    C  1877.0         1
# 4           0       3    male  35.0   8.0500        S  NaN  1877.0         0
# ..        ...     ...     ...   ...      ...      ...  ...     ...       ...
# 886         0       2    male  27.0  13.0000        S  NaN  1885.0         0
# 887         1       1  female  19.0  30.0000        S    B  1893.0         0
# 888         0       3  female   NaN  23.4500        S  NaN     NaN         3
# 889         1       1    male  26.0  30.0000        C    C  1886.0         0
# 890         0       3    male  32.0   7.7500        Q  NaN  1880.0         0
#
# [891 rows x 9 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/dx/tzmn0d1j2cn3c33_rdvb0jxw0000gn/T/ipykernel_31948/1330922439.py in <module>
# ----> 1 data['Engine Fuel Type'].unique()
#
# NameError: name 'data' is not defined
